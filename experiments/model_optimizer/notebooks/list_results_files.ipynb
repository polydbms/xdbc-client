# %%
import pandas as pd
import glob
import yaml


all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')

algos_to_view = [
        #"cost_model_rfs_rs_exc_cluster_update_net_trans",
        #"cost_model_rfs_rs_exc_cluster_update_only_hist",

        #"cost_model_rfs_bay_exc_cluster_update_net_trans",
        #"cost_model_rfs_bay_exc_cluster_update_only_hist",
    
        #"cost_model_rfs_rs_exc_cluster_update_net_trans_currated_data",
        #"cost_model_rfs_rs_exc_cluster_update_only_hist_currated_data",
    

        #"cost_model_gdb_rs_exc_cluster_update_net_trans",
        #"cost_model_gdb_rs_exc_cluster_update_only_hist",

        #"cost_model_xgb_rs_exc_cluster_update_net_trans",
        #"cost_model_xgb_rs_exc_cluster_update_only_hist",

        "cost_model_xgb_rs_exc_cluster_update_net_trans_tuned",
        "cost_model_xgb_rs_exc_cluster_update_only_hist_tuned",
    
        #"tlbo_rgpe_prf",
        #"tlbo_topov3_prf",
        #"quantile",
        #"bayesian_open_box",
        #"random_search_syne_tune"

]

all_envs = []
all_algos = []
total_count = 0
dict_overview = dict();


dict_count_per_env = dict();

for file in all_files:
    df = pd.read_csv(file)

    env = file.split("\\")[-3]
    algo = file.split("\\")[-2]
    count = len(df[df['transfer_id'] > 0])

    #if algo not in algos_to_view:
    #    continue

    if not any(a in algo for a in algos_to_view):
        continue
    if "_hist_ratio" in algo:
        continue


    
    total_count = total_count + count
    
    if env not in dict_overview.keys() :
        dict_overview[env] = dict()
    if algo not in dict_overview[env].keys(): 
        dict_overview[env][algo] = ""

    if env not in dict_count_per_env.keys():  
        dict_count_per_env[env] = 0
    
    dict_overview[env][algo] = dict_overview[env][algo] + "" + str(count)+"x; "
    dict_count_per_env[env] = dict_count_per_env[env] + count

print(yaml.dump(dict_overview))
print(yaml.dump(dict_count_per_env))
print("Total Transfer Count : "+str(total_count))
# Out:
# S16_C16_N1000:
#   cost_model_xgb_rs_exc_cluster_update_net_trans_tuned: '25x; 25x; 24x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_tuned: '24x; 25x; 24x; '
# S16_C16_N150:
#   cost_model_xgb_rs_exc_cluster_update_net_trans_tuned: '24x; 25x; 23x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_tuned: '24x; 22x; 22x; '
# S16_C16_N50:
#   cost_model_xgb_rs_exc_cluster_update_net_trans_tuned: '25x; 25x; 24x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_tuned: '25x; 25x; 25x; '
# S2_C2_N1000:
#   cost_model_xgb_rs_exc_cluster_update_net_trans_tuned: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_tuned: '24x; 25x; 25x; '
# S2_C2_N150:
#   cost_model_xgb_rs_exc_cluster_update_net_trans_tuned: '24x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_tuned: '25x; 24x; 25x; '
# S2_C2_N50:
#   cost_model_xgb_rs_exc_cluster_update_net_trans_tuned: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_tuned: '25x; 25x; 25x; '
# S8_C2_N1000:
#   cost_model_xgb_rs_exc_cluster_update_net_trans_tuned: '10x; 21x; 22x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_tuned: '19x; 19x; 20x; '
# S8_C2_N150:
#   cost_model_xgb_rs_exc_cluster_update_net_trans_tuned: '24x; 24x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_tuned: '23x; 21x; 22x; '
# S8_C2_N50:
#   cost_model_xgb_rs_exc_cluster_update_net_trans_tuned: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_tuned: '25x; 25x; 25x; '
#
# S16_C16_N1000: 147
# S16_C16_N150: 140
# S16_C16_N50: 149
# S2_C2_N1000: 149
# S2_C2_N150: 148
# S2_C2_N50: 150
# S8_C2_N1000: 111
# S8_C2_N150: 139
# S8_C2_N50: 150
#
# Total Transfer Count : 1283

# %%
import pandas as pd
import glob
import yaml

#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_*/S*.csv')
all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_1310k/S*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_175k/S*.csv')

total_count = 0

for file in all_files:
    df = pd.read_csv(file)

   
    count = len(df[df['time'].notna()])
    #count = len(df['time'])
    
    total_count = total_count + count

    print(f"{file.split('\\')[-1].split(".")[0]} : {count}")

print("\nTotal Random Sample Count : "+str(total_count))
# Out:
# S16_C16_N10000_random_samples : 4
# S16_C16_N1000_random_samples : 325
# S16_C16_N100_random_samples : 42
# S16_C16_N150_random_samples : 325
# S16_C16_N200_random_samples : 62
# S16_C16_N20_random_samples : 57
# S16_C16_N300_random_samples : 64
# S16_C16_N400_random_samples : 64
# S16_C16_N500_random_samples : 43
# S16_C16_N50_random_samples : 325
# S16_C16_N600_random_samples : 64
# S16_C16_N700_random_samples : 65
# S16_C16_N800_random_samples : 65
# S16_C16_N900_random_samples : 65
# S16_C2_N1000_random_samples : 60
# S16_C4_N1000_random_samples : 325
# S16_C4_N150_random_samples : 325
# S16_C4_N50_random_samples : 325
# S16_C8_N1000_random_samples : 325
# S16_C8_N150_random_samples : 325
# S16_C8_N50_random_samples : 325
# S2_C16_N1000_random_samples : 66
# S2_C2_N1000_random_samples : 325
# S2_C2_N150_random_samples : 325
# S2_C2_N50_random_samples : 350
# S2_C4_N1000_random_samples : 65
# S2_C8_N1000_random_samples : 325
# S2_C8_N150_random_samples : 325
# S2_C8_N50_random_samples : 350
# S4_C16_N1000_random_samples : 325
# S4_C16_N150_random_samples : 325
# S4_C16_N50_random_samples : 350
# S4_C2_N1000_random_samples : 65
# S4_C4_N1000_random_samples : 64
# S4_C4_N150_random_samples : 20
# S4_C4_N50_random_samples : 20
# S4_C8_N1000_random_samples : 64
# S8_C16_N1000_random_samples : 65
# S8_C2_N1000_random_samples : 325
# S8_C2_N150_random_samples : 325
# S8_C2_N50_random_samples : 348
# S8_C4_N1000_random_samples : 65
# S8_C8_N1000_random_samples : 324
# S8_C8_N150_random_samples : 325
# S8_C8_N50_random_samples : 350
#
# Total Random Sample Count : 9071

# %%
import pandas as pd
import glob
import yaml


# get all files where there are more than 4 timeouts



all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_175k/*/*/*.csv')

total_count = 0

for file in all_files:
    df = pd.read_csv(file)

    count_all = len(df['time'])
    
    df = df[df['transfer_id'] > 0]    
    
    count = len(df[df['time'].notna()])


    if (count_all - count) > 5:

        print(f"{file.split('\\')[-1].split(".")[0]} : {(count_all - count)}")
        print(file)
        print("\n")
# Out:
# results_cost_model_rfs_rs_exc_cluster_update_hist_ratio_2025-01-28_01-08-58 : 6
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S16_C16_N150\cost_model_rfs_rs_exc_cluster_update_hist_ratio\results_cost_model_rfs_rs_exc_cluster_update_hist_ratio_2025-01-28_01-08-58.csv
#
#
# results_cost_model_rfs_rs_exc_cluster_update_2025-01-28_12-18-52 : 6
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_cluster_update\results_cost_model_rfs_rs_exc_cluster_update_2025-01-28_12-18-52.csv
#
#
# results_cost_model_rfs_rs_exc_cluster_update_net_trans_hist_ratio_2025-01-28_22-10-06 : 6
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_cluster_update_net_trans_hist_ratio\results_cost_model_rfs_rs_exc_cluster_update_net_trans_hist_ratio_2025-01-28_22-10-06.csv
#
#
# results_cost_model_rfs_rs_exc_update_hist_ratio_2025-01-28_15-54-50 : 6
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_update_hist_ratio\results_cost_model_rfs_rs_exc_update_hist_ratio_2025-01-28_15-54-50.csv
#
#
# results_cost_model_rfs_rs_exc_update_net_trans_hist_ratio_2025-01-28_04-10-09 : 7
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_update_net_trans_hist_ratio\results_cost_model_rfs_rs_exc_update_net_trans_hist_ratio_2025-01-28_04-10-09.csv
#
#
# results_cost_model_rfs_rs_exc_update_only_hist_2025-01-28_19-41-10 : 10
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_update_only_hist\results_cost_model_rfs_rs_exc_update_only_hist_2025-01-28_19-41-10.csv
#
#
# results_cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_2025-01-23_15-47-06 : 6
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err\results_cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_2025-01-23_15-47-06.csv
#
#
# results_cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_2025-01-23_19-12-28 : 7
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err\results_cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_2025-01-23_19-12-28.csv
#
#
# results_cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_net_trans_2025-01-24_13-35-41 : 7
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_net_trans\results_cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_net_trans_2025-01-24_13-35-41.csv
#
#
# results_cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_net_trans_2025-01-24_20-03-39 : 6
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_net_trans\results_cost_model_rfs_rs_exc_w_updatehist_w_ratio_sqr_err_net_trans_2025-01-24_20-03-39.csv
#
#
# results_cost_model_rfs_rs_exc_w_update_clusterhist_w_ratio_sqr_err_net_trans_2025-01-24_15-06-47 : 6
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S8_C2_N1000\cost_model_rfs_rs_exc_w_update_clusterhist_w_ratio_sqr_err_net_trans\results_cost_model_rfs_rs_exc_w_update_clusterhist_w_ratio_sqr_err_net_trans_2025-01-24_15-06-47.csv
