# %%
import pandas as pd
import glob
import yaml


#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_6250k/*/*/*.csv')

all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k_shorter_runs/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_175k/*/*/*.csv')




all_envs = []
all_algos = []
total_count = 0
dict_overview = dict();


dict_count_per_env = dict();

for file in all_files:
    df = pd.read_csv(file)

    env = file.split("\\")[-3]
    algo = file.split("\\")[-2]
    count = len(df[df['time'] > 0])

    total_count = total_count + count

    #print("Env : "+str(env)+"   Algo : "+str(algo)+"   Count : "+str(count))
    
    if env not in dict_overview.keys() :
        dict_overview[env] = dict()
    if algo not in dict_overview[env].keys(): 
        dict_overview[env][algo] = ""

    if env not in dict_count_per_env.keys():  
        dict_count_per_env[env] = 0
    
    dict_overview[env][algo] = dict_overview[env][algo] + "" + str(count)+"x;"
    dict_count_per_env[env] = dict_count_per_env[env] + count

print(yaml.dump(dict_overview))
print(yaml.dump(dict_count_per_env))
print("Total Transfer Count : "+str(total_count))
# Out:
# S16_C16_N1000:
#   random_search_syne_tune: 25x;25x;
#   tlbo_rgpe_prf_exc_S16C16N1000_S16C8N1000_open_box_n_100: 25x;
#   tlbo_topov3_prf_exc_S16C16N1000_S16C8N1000_open_box_n_100: 8x;
# S16_C16_N150:
#   quantile_exc_S16C16N150_S8C8N150_syne_tune_n_100: 25x;
#   random_search_syne_tune: 25x;25x;
#   tlbo_rgpe_prf_exc_S16C16N150_S8C8N150_open_box_n_100: 25x;
#   tlbo_topov3_prf_exc_S16C16N150_S8C8N150_open_box_n_100: 25x;
# S16_C16_N50:
#   quantile_exc_S16C16N50_S8C8N50_syne_tune_n_100: 25x;
#   random_search_syne_tune: 25x;25x;
#   tlbo_rgpe_prf_exc_S16C16N50_S8C8N50_open_box_n_100: 25x;
#   tlbo_topov3_prf_exc_S16C16N50_S8C8N50_open_box_n_100: 25x;
# S2_C2_N1000:
#   quantile_exc_S2C2N1000_S2C8N1000_syne_tune_n_100: 25x;
#   random_search_syne_tune: 25x;25x;
#   tlbo_rgpe_prf_exc_S2C2N1000_S2C8N1000_open_box_n_100: 25x;
#   tlbo_topov3_prf_exc_S2C2N1000_S2C8N1000_open_box_n_100: 25x;
# S2_C2_N150:
#   quantile_exc_S2C2N150_S2C8N150_syne_tune_n_100: 25x;
#   random_search_syne_tune: 25x;25x;
#   tlbo_rgpe_prf_exc_S2C2N150_S2C8N150_open_box_n_100: 25x;
#   tlbo_topov3_prf_exc_S2C2N150_S2C8N150_open_box_n_100: 25x;
# S2_C2_N50:
#   quantile_exc_S2C2N50_S2C8N50_syne_tune_n_100: 25x;
#   quantile_exc_S2C2N50_S2C8N50_syne_tune_with_clustering_n_100: 5x;
#   random_search_syne_tune: 25x;25x;
#   tlbo_rgpe_prf_exc_S2C2N50_S2C8N50_open_box_n_100: 25x;
#   tlbo_rgpe_prf_exc_S2C2N50_S2C8N50_open_box_with_clustering_n_100: 4x;
#   tlbo_topov3_prf_exc_S2C2N50_S2C8N50_open_box_n_100: 21x;
#   tlbo_topov3_prf_exc_S2C2N50_S2C8N50_open_box_with_clustering_n_100: 3x;
# S8_C2_N1000:
#   quantile_exc_S8C2N1000_S8C8N1000_syne_tune_n_100: 25x;
#   random_search_syne_tune: 20x;25x;
#   tlbo_rgpe_prf_exc_S8C2N1000_S8C8N1000_open_box_n_100: 25x;
#   tlbo_topov3_prf_exc_S8C2N1000_S8C8N1000_open_box_n_100: 20x;
# S8_C2_N150:
#   quantile_exc_S8C2N150_S8C8N150_syne_tune_n_100: 25x;
#   random_search_syne_tune: 25x;25x;
#   tlbo_rgpe_prf_exc_S8C2N150_S8C8N150_open_box_n_100: 25x;
#   tlbo_topov3_prf_exc_S8C2N150_S8C8N150_open_box_n_100: 25x;
# S8_C2_N50:
#   quantile_exc_S8C2N50_S8C8N50_syne_tune_n_100: 25x;
#   random_search_syne_tune: 25x;25x;
#   tlbo_rgpe_prf_exc_S8C2N50_S8C8N50_open_box_n_100: 25x;
#   tlbo_topov3_prf_exc_S8C2N50_S8C8N50_open_box_n_100: 25x;
#
# S16_C16_N1000: 83
# S16_C16_N150: 125
# S16_C16_N50: 125
# S2_C2_N1000: 125
# S2_C2_N150: 125
# S2_C2_N50: 133
# S8_C2_N1000: 115
# S8_C2_N150: 125
# S8_C2_N50: 125
#
# Total Transfer Count : 1081

# %%
import pandas as pd
import glob
import yaml

#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_*/S*.csv')
all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_1310k/S*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_175k/S*.csv')

total_count = 0

for file in all_files:
    df = pd.read_csv(file)

    #if "N1000" not in file:
    #if "S16_C16_N" not in file:
    #    continue
    
    #df = df[df['time'] > 0]    
    count = len(df[df['time'].notna()])
    #count = len(df['time'])
    
    total_count = total_count + count

    print(f"{file.split('\\')[-1].split(".")[0]} : {count}")

print("\nTotal Random Sample Count : "+str(total_count))
# Out:
# S16_C16_N10000_random_samples : 4
# S16_C16_N1000_random_samples : 97
# S16_C16_N100_random_samples : 42
# S16_C16_N150_random_samples : 100
# S16_C16_N200_random_samples : 62
# S16_C16_N20_random_samples : 57
# S16_C16_N300_random_samples : 64
# S16_C16_N400_random_samples : 64
# S16_C16_N500_random_samples : 43
# S16_C16_N50_random_samples : 100
# S16_C16_N600_random_samples : 64
# S16_C16_N700_random_samples : 65
# S16_C16_N800_random_samples : 65
# S16_C16_N900_random_samples : 65
# S16_C2_N1000_random_samples : 60
# S16_C4_N1000_random_samples : 100
# S16_C4_N150_random_samples : 100
# S16_C4_N50_random_samples : 101
# S16_C8_N1000_random_samples : 100
# S16_C8_N150_random_samples : 100
# S16_C8_N50_random_samples : 100
# S2_C16_N1000_random_samples : 66
# S2_C2_N1000_random_samples : 100
# S2_C2_N150_random_samples : 100
# S2_C2_N50_random_samples : 101
# S2_C4_N1000_random_samples : 65
# S2_C8_N1000_random_samples : 100
# S2_C8_N150_random_samples : 100
# S2_C8_N50_random_samples : 101
# S4_C16_N1000_random_samples : 100
# S4_C16_N150_random_samples : 100
# S4_C16_N50_random_samples : 101
# S4_C2_N1000_random_samples : 65
# S4_C4_N1000_random_samples : 64
# S4_C4_N150_random_samples : 20
# S4_C4_N50_random_samples : 20
# S4_C8_N1000_random_samples : 64
# S8_C16_N1000_random_samples : 65
# S8_C2_N1000_random_samples : 100
# S8_C2_N150_random_samples : 100
# S8_C2_N50_random_samples : 101
# S8_C4_N1000_random_samples : 65
# S8_C8_N1000_random_samples : 100
# S8_C8_N150_random_samples : 100
# S8_C8_N50_random_samples : 101
#
# Total Random Sample Count : 3552

# %%
import pandas as pd
import glob
import yaml


# get all files where there are more than 4 timeouts



all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_175k/*/*/*.csv')

total_count = 0

for file in all_files:
    df = pd.read_csv(file)

    count_all = len(df['time'])
    
    df = df[df['time'] > 0]    
    
    count = len(df[df['time'].notna()])


    if (count_all - count) > 7:

        print(f"{file.split('\\')[-1].split(".")[0]} : {(count_all - count)}")
        print(file)
        print("\n")
# Out:
# results_tlbo_topov3_prf_exc_S2C2N50_S2C8N50_open_box_n_100_2025-01-18_12-41-34 : 35
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k\S2_C2_N50\tlbo_topov3_prf_exc_S2C2N50_S2C8N50_open_box_n_100\results_tlbo_topov3_prf_exc_S2C2N50_S2C8N50_open_box_n_100_2025-01-18_12-41-34.csv
