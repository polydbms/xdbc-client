# %%
import pandas as pd
import glob
import yaml


all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_10_5M/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')

algos_to_view = [
        #"cost_model_xgb_rs_exc_cluster_net_trans",
        #"cost_model_xgb_rs_exc_cluster_update_net_trans",
        #"cost_model_xgb_rs_exc_cluster_update_only_hist",

        #"tlbo_rgpe_prf",
        #"tlbo_topov3_prf",
        #"quantile",
        #"bayesian_open_box",
        #"random_search_syne_tune"

]

all_envs = []
all_algos = []
total_count = 0
dict_overview = dict();


dict_count_per_env = dict();

for file in all_files:
    #print(file)
    df = pd.read_csv(file)

    env = file.split("\\")[-3]
    algo = file.split("\\")[-2]
    count = len(df[df['transfer_id'] > 0])

    #if algo not in algos_to_view:
    #    continue

    #if not any(a in algo for a in algos_to_view):
    #    continue

    total_count = total_count + count
    
    if env not in dict_overview.keys() :
        dict_overview[env] = dict()
    if algo not in dict_overview[env].keys(): 
        dict_overview[env][algo] = ""

    if env not in dict_count_per_env.keys():  
        dict_count_per_env[env] = 0
    
    dict_overview[env][algo] = dict_overview[env][algo] + "" + str(count)+"x; "
    dict_count_per_env[env] = dict_count_per_env[env] + count

print(yaml.dump(dict_overview))
print(yaml.dump(dict_count_per_env))
print("Total Transfer Count : "+str(total_count))
# Out:
# S16_C16_N1000:
#   bayesian_open_box: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist: '25x; 24x; 24x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v2: '24x; 24x; 24x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v3: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v4: '24x; 25x; 25x; '
#   random_search_syne_tune: '25x; 25x; 25x; 25x; '
#   tlbo_rgpe_prf_exc_S16C16N1000_S8C16N1000_open_box_with_clustering_n_400: '25x; 25x;
#     25x; '
# S16_C4_N1000:
#   bayesian_open_box: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v2: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v3: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v4: '25x; 25x; 25x; '
#   random_search_syne_tune: '25x; 25x; 25x; 25x; '
#   tlbo_rgpe_prf_exc_S16C4N1000_S16C4N150_open_box_with_clustering_n_400: '25x; 25x;
#     25x; '
#   tlbo_topov3_prf_exc_S16C4N1000_S16C4N150_open_box_with_clustering_n_400: '13x; 6x; '
# S16_C8_N1000:
#   bayesian_open_box: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist: '25x; 25x; 24x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v2: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v3: '24x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v4: '25x; 25x; 25x; '
#   random_search_syne_tune: '25x; 25x; 25x; 25x; '
#   tlbo_rgpe_prf_exc_S16C8N1000_S8C8N1000_open_box_with_clustering_n_400: '25x; '
# S2_C2_N50:
#   bayesian_open_box: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist: '23x; 23x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v2: '25x; 19x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v3: '24x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v4: '24x; 25x; 24x; '
#   random_search_syne_tune: '25x; 25x; 25x; 25x; '
#   tlbo_rgpe_prf_exc_S2C2N50_S8C2N50_open_box_with_clustering_n_400: '25x; 25x; 25x; '
#   tlbo_topov3_prf_exc_S2C2N50_S8C2N50_open_box_with_clustering_n_400: '18x; 16x; 17x; '
# S2_C8_N50:
#   bayesian_open_box: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v2: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v3: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v4: '24x; 25x; 24x; '
#   random_search_syne_tune: '25x; 25x; 25x; 25x; '
#   tlbo_rgpe_prf_exc_S2C8N50_S4C16N50_open_box_with_clustering_n_400: '25x; 25x; 24x; '
#   tlbo_topov3_prf_exc_S2C8N50_S4C16N50_open_box_with_clustering_n_400: '19x; 14x;
#     11x; '
# S4_C16_N50:
#   bayesian_open_box: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v2: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v3: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v4: '25x; 25x; 25x; '
#   random_search_syne_tune: '25x; 25x; 25x; 25x; '
#   tlbo_rgpe_prf_exc_S4C16N50_S8C8N50_open_box_with_clustering_n_400: '25x; 25x; '
#   tlbo_topov3_prf_exc_S4C16N50_S8C8N50_open_box_with_clustering_n_400: '12x; 11x; '
# S8_C16_N150:
#   bayesian_open_box: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v2: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v3: '24x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v4: '24x; 24x; 24x; '
#   random_search_syne_tune: '25x; 25x; 25x; 25x; '
#   tlbo_rgpe_prf_exc_S8C16N150_S16C16N150_open_box_with_clustering_n_400: '25x; 25x;
#     25x; '
# S8_C2_N150:
#   bayesian_open_box: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist: '24x; 24x; 24x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v2: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v3: '23x; 25x; 23x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v4: '25x; 25x; 25x; '
#   random_search_syne_tune: '25x; 25x; 25x; 25x; '
#   tlbo_rgpe_prf_exc_S8C2N150_S8C2N1000_open_box_with_clustering_n_400: '25x; '
#   tlbo_topov3_prf_exc_S8C2N150_S8C2N1000_open_box_with_clustering_n_400: '18x; 18x;
#     17x; '
# S8_C8_N150:
#   bayesian_open_box: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v2: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v3: '25x; 25x; 25x; '
#   cost_model_xgb_rs_exc_cluster_update_only_hist_v4: '25x; 25x; 25x; '
#   random_search_syne_tune: '25x; 25x; 25x; 25x; '
#   tlbo_rgpe_prf_exc_S8C8N150_S16C8N150_open_box_with_clustering_n_400: '25x; 25x;
#     25x; '
#
# S16_C16_N1000: 544
# S16_C4_N1000: 569
# S16_C8_N1000: 498
# S2_C2_N50: 588
# S2_C8_N50: 591
# S4_C16_N50: 548
# S8_C16_N150: 546
# S8_C2_N150: 546
# S8_C8_N150: 550
#
# Total Transfer Count : 4980

# %%
import pandas as pd
import glob
import yaml
all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_10_5M/S*.csv')
total_count = 0
for file in all_files:
    df = pd.read_csv(file)   
    count = len(df[df['time'].notna()])
    #count = len(df[df['transfer_id']>0])
    total_count = total_count + count
    print(f"{file.split('\\')[-1].split(".")[0]} : {count}")
print("\nTotal Random Sample Count : "+str(total_count))
# Out:
# S16_C16_N1000_random_samples : 450
# S16_C16_N150_random_samples : 450
# S16_C16_N50_random_samples : 450
# S16_C4_N1000_random_samples : 450
# S16_C4_N150_random_samples : 450
# S16_C4_N50_random_samples : 450
# S16_C8_N1000_random_samples : 450
# S16_C8_N150_random_samples : 450
# S16_C8_N50_random_samples : 450
# S2_C2_N1000_random_samples : 450
# S2_C2_N150_random_samples : 450
# S2_C2_N50_random_samples : 450
# S2_C8_N1000_random_samples : 450
# S2_C8_N150_random_samples : 450
# S2_C8_N50_random_samples : 450
# S4_C16_N1000_random_samples : 450
# S4_C16_N150_random_samples : 450
# S4_C16_N50_random_samples : 450
# S8_C16_N1000_random_samples : 450
# S8_C16_N150_random_samples : 450
# S8_C16_N50_random_samples : 450
# S8_C2_N1000_random_samples : 450
# S8_C2_N150_random_samples : 450
# S8_C2_N50_random_samples : 450
# S8_C8_N1000_random_samples : 450
# S8_C8_N150_random_samples : 450
# S8_C8_N50_random_samples : 450
#
# Total Random Sample Count : 12150

# %%
import pandas as pd
import glob
import yaml
all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')
total_count = 0
for file in all_files:
    df = pd.read_csv(file)
    count_all = len(df['time'])
    df = df[df['transfer_id'] > 0]    
    
    count = len(df[df['time'].notna()])


    if (count_all - count) > 5:

        print(f"{file.split('\\')[-1].split(".")[0]} : {(count_all - count)}")
        print(file)
        print("\n")

# %%
import pandas as pd
import glob
import yaml
all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')

for file in all_files:
    df = pd.read_csv(file)
    if 'predicted_time' in df.columns:
        
        if 'uncompressed_throughput' not in df.columns:
            df['uncompressed_throughput'] = (7715741636 / 1000 / 1000) / df['time']
    
        df['predicted_throughput'] =  (7715741636 / 1000 / 1000) / df['predicted_time']
        #df.to_csv(file, index=False)
