# %%
import pandas as pd
import glob
import yaml


#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_6250k/*/*/*.csv')

all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_175k/*/*/*.csv')




all_envs = []
all_algos = []
total_count = 0
dict_overview = dict();


dict_count_per_env = dict();

for file in all_files:
    df = pd.read_csv(file)

    env = file.split("\\")[-3]
    algo = file.split("\\")[-2]
    count = len(df[df['time'] > 0])

    total_count = total_count + count

    #print("Env : "+str(env)+"   Algo : "+str(algo)+"   Count : "+str(count))
    
    if env not in dict_overview.keys() :
        dict_overview[env] = dict()
    if algo not in dict_overview[env].keys(): 
        dict_overview[env][algo] = ""

    if env not in dict_count_per_env.keys():  
        dict_count_per_env[env] = 0
    
    dict_overview[env][algo] = dict_overview[env][algo] + "" + str(count)+"x;"
    dict_count_per_env[env] = dict_count_per_env[env] + count

print(yaml.dump(dict_overview))
print(yaml.dump(dict_count_per_env))
print("Total Transfer Count : "+str(total_count))
# Out:
# S16_C16_N1000:
#   bayesian_open_box: 63x;14x;69x;
#   bayesian_syne_tune: 142x;32x;100x;
#   random_search_syne_tune: 150x;19x;100x;
# S16_C16_N10000:
#   bayesian_syne_tune: 42x;
#   random_search_syne_tune: 100x;
# S16_C8_N100:
#   bayesian_open_box: 47x;9x;38x;
#   bayesian_syne_tune: 74x;63x;
#   random_search_syne_tune: 100x;
# S8_C1_N50:
#   bayesian_open_box: 25x;
#   bayesian_syne_tune: 86x;
#   random_search_syne_tune: 61x;
# S8_C8_N500:
#   bayesian_syne_tune: 13x;
#
# S16_C16_N1000: 689
# S16_C16_N10000: 142
# S16_C8_N100: 331
# S8_C1_N50: 172
# S8_C8_N500: 13
#
# Total Transfer Count : 1347

# %%
import pandas as pd
import glob
import yaml

#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_*/S*.csv')
all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_1310k/S*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_175k/S*.csv')

total_count = 0

for file in all_files:
    df = pd.read_csv(file)
    
    #df = df[df['time'] > 0]    
    #count = len(df[df['time'].notna()])
    count = len(df['time'])
    
    total_count = total_count + count

    print(f"{file.split('\\')[-1].split(".")[0]} : {count}")

print("\nTotal Random Sample Count : "+str(total_count))
# Out:
# S16_C16_N10000_random_samples : 550
# S16_C16_N1000_random_samples : 550
# S16_C1_N1000_random_samples : 550
# S16_C1_N10_random_samples : 550
# S16_C4_N10_random_samples : 520
# S16_C8_N100_random_samples : 550
# S2_C2_N20_random_samples : 550
# S8_C1_N50_random_samples : 550
# S8_C8_N500_random_samples : 550
#
# Total Random Sample Count : 4920

# %%
import pandas as pd
import glob
import yaml


# get all files where there are more than 4 timeouts



all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results*/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_1310k/*/*/*.csv')
#all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_175k/*/*/*.csv')

total_count = 0

for file in all_files:
    df = pd.read_csv(file)

    count_all = len(df['time'])
    
    df = df[df['time'] > 0]    
    
    count = len(df[df['time'].notna()])


    if (count_all - count) > 7:

        print(f"{file.split('\\')[-1].split(".")[0]} : {(count_all - count)}")
        print(file)
        print("\n")
# Out:
# results_tlbo_topov3_gp_exc_env1_env4_open_box_2024-12-21_00-22-41 : 8
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S16_C16_N1000\tlbo_topov3_gp_exc_env1_env4_open_box\results_tlbo_topov3_gp_exc_env1_env4_open_box_2024-12-21_00-22-41.csv
#
#
# results_tlbo_topov3_gp_all_envs_open_box_2024-12-17_10-57-09 : 25
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S16_C16_N10000\tlbo_topov3_gp_all_envs_open_box\results_tlbo_topov3_gp_all_envs_open_box_2024-12-17_10-57-09.csv
#
#
# results_tlbo_topov3_gp_exc_env1_env4_open_box_2024-12-17_11-55-26 : 20
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S16_C16_N10000\tlbo_topov3_gp_exc_env1_env4_open_box\results_tlbo_topov3_gp_exc_env1_env4_open_box_2024-12-17_11-55-26.csv
#
#
# results_tlbo_topov3_gp_exc_env1_env4_open_box_2024-12-21_08-53-51 : 27
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S16_C16_N10000\tlbo_topov3_gp_exc_env1_env4_open_box\results_tlbo_topov3_gp_exc_env1_env4_open_box_2024-12-21_08-53-51.csv
#
#
# results_bayesian_syne_tune_2024-12-11_18-28-14 : 9
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S16_C4_N10\bayesian_syne_tune\results_bayesian_syne_tune_2024-12-11_18-28-14.csv
#
#
# results_transfer_exc_env2_env5_open_box_2024-12-10_17-15-13 : 8
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S16_C4_N10\tlbo_rgpe_prf_exc_env2_env5_open_box\results_transfer_exc_env2_env5_open_box_2024-12-10_17-15-13.csv
#
#
# results_random_search_syne_tune_2024-12-15_10-53-22 : 8
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S16_C8_N100\random_search_syne_tune\results_random_search_syne_tune_2024-12-15_10-53-22.csv
#
#
# results_tlbo_sgpr_prf_exc_env2_env5_open_box_2024-12-21_01-30-06 : 49
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S16_C8_N100\tlbo_sgpr_prf_exc_env2_env5_open_box\results_tlbo_sgpr_prf_exc_env2_env5_open_box_2024-12-21_01-30-06.csv
#
#
# results_tlbo_rgpe_prf_exc_env6_env7_open_box_2024-12-20_06-36-16 : 14
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S2_C2_N20\tlbo_rgpe_prf_exc_env6_env7_open_box\results_tlbo_rgpe_prf_exc_env6_env7_open_box_2024-12-20_06-36-16.csv
#
#
# results_bayesian_open_box_2024-12-13_16-58-43 : 9
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_1310k\S8_C8_N500\bayesian_open_box\results_bayesian_open_box_2024-12-13_16-58-43.csv
#
#
# results_bayesian_open_box_2024-12-12_20-43-42 : 11
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_175k\S16_C8_N100\bayesian_open_box\results_bayesian_open_box_2024-12-12_20-43-42.csv
#
#
# results_bayesian_syne_tune_2024-12-15_13-45-36 : 14
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_6250k\S16_C16_N1000\bayesian_syne_tune\results_bayesian_syne_tune_2024-12-15_13-45-36.csv
#
#
# results_bayesian_open_box_2024-12-15_14-31-32 : 11
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_6250k\S16_C8_N100\bayesian_open_box\results_bayesian_open_box_2024-12-15_14-31-32.csv
#
#
# results_bayesian_syne_tune_2024-12-15_14-31-37 : 11
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_6250k\S16_C8_N100\bayesian_syne_tune\results_bayesian_syne_tune_2024-12-15_14-31-37.csv
#
#
# results_random_search_syne_tune_2024-12-15_13-45-39 : 11
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_6250k\S16_C8_N100\random_search_syne_tune\results_random_search_syne_tune_2024-12-15_13-45-39.csv
#
#
# results_bayesian_open_box_2024-12-15_16-53-20 : 30
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_96636M\S16_C16_N1000\bayesian_open_box\results_bayesian_open_box_2024-12-15_16-53-20.csv
#
#
# results_bayesian_syne_tune_2024-12-15_16-53-23 : 14
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_96636M\S16_C16_N1000\bayesian_syne_tune\results_bayesian_syne_tune_2024-12-15_16-53-23.csv
#
#
# results_random_search_syne_tune_2024-12-15_16-53-18 : 13
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_96636M\S16_C16_N1000\random_search_syne_tune\results_random_search_syne_tune_2024-12-15_16-53-18.csv
#
#
# results_bayesian_open_box_2024-12-15_19-17-55 : 11
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_96636M\S16_C8_N100\bayesian_open_box\results_bayesian_open_box_2024-12-15_19-17-55.csv
#
#
# results_bayesian_syne_tune_2024-12-15_19-19-42 : 11
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_96636M\S16_C8_N100\bayesian_syne_tune\results_bayesian_syne_tune_2024-12-15_19-19-42.csv
#
#
# results_random_search_syne_tune_2024-12-15_16-53-25 : 10
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_96636M\S16_C8_N100\random_search_syne_tune\results_random_search_syne_tune_2024-12-15_16-53-25.csv
