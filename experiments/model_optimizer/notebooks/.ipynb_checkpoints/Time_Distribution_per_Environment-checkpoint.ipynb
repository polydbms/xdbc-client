# %%
import glob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np

import glob
import pandas as pd
import seaborn as sns
import statistics
import numpy as np
import pandas as pd
import seaborn as sns
import glob, os
import matplotlib.pyplot as plt

def get_file_list(base_path, signatures):
    """Generate file lists for the given base path and environment signatures."""
    return [glob.glob(f"{base_path}/{signature}_random_sample*.csv") for signature in signatures]

def load_and_filter_data(file_list, max_config_id, time_threshold=2):
    """Load and filter data based on time and config_id."""
    data_frames = []
    for file in file_list:
        df = pd.read_csv(file)
        df = df[(df['time'] > time_threshold) & (df['config_id'] < max_config_id)]
        data_frames.append(df)
    return pd.concat(data_frames, axis=0, ignore_index=True) if data_frames else pd.DataFrame()

BASE_PATH = "C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_10_5M"


ENV_SIGNATURES_NEW_BASE_ENVS = [
    "S2_C2_N50","S2_C8_N50","S4_C16_N50","S8_C8_N50","S8_C2_N50","S8_C16_N50","S16_C4_N50","S16_C8_N50","S16_C16_N50",
                             "S2_C2_N150","S2_C8_N150","S4_C16_N150","S8_C8_N150","S8_C2_N150","S8_C16_N150","S16_C4_N150","S16_C8_N150","S16_C16_N150",
                             "S2_C2_N1000","S2_C8_N1000","S4_C16_N1000","S8_C8_N1000","S8_C2_N1000","S8_C16_N1000","S16_C4_N1000","S16_C8_N1000","S16_C16_N1000"
]


env_lists = {
    #"SCALE_COMPUTE": ENV_SIGNATURES_SCALE_COMPUTE,
    #"SCALE_NETWORK": ENV_SIGNATURES_SCALE_NETWORK,
    "NEW_BASE":ENV_SIGNATURES_NEW_BASE_ENVS,
    #"ALL_ORIG": ENV_SIGNATURES_ALL,
    #"TRUE_ALL": list(set(ENV_SIGNATURES_SCALE_NETWORK).union(ENV_SIGNATURES_SCALE_COMPUTE, ENV_SIGNATURES_ALL))
    #"SCALE_BOTH": list(set(ENV_SIGNATURES_SCALE_NETWORK).union(ENV_SIGNATURES_SCALE_COMPUTE))
}

for name, env_list in env_lists.items():
    
    file_lists = get_file_list(BASE_PATH, env_list)
    df_heatmap = pd.DataFrame(0, index=env_list, columns=env_list, dtype=float)
    
    N = 66
    for i, file_list in enumerate(file_lists):

        env = ""
        algo = ""
    
        all_data = pd.DataFrame()
        list_single_dfs_1310k = []
    
        for file in file_list:
    
            env = file.split("/")[-1].split("\\")[1].split("_random")[0]
            algo = file.split("\\")[-2]
    
            df = pd.read_csv(file)
            df = df[df['time'] > 1]
    
            df = df[df['config_id'] < 500]
    
            list_single_dfs_1310k.append(df)
        try:   
            all_data = pd.concat(list_single_dfs_1310k, axis=0, ignore_index=True)
        
            all_data = all_data.sort_values(by='time',ascending=False).reset_index()
            
            
            print(f"Max transfer time for env {env} :     {all_data['time'].max()}")
            print(f"Average transfer time for env {env} : {statistics.mean(all_data['time'])}")
            print(f"Min transfer time for env {env} :     {all_data['time'].min()}")
            print(f"Max throughput for env {env} :     {all_data['uncompressed_throughput'].max()}")
            
            plt.figure(figsize=(8, 5))
            
            plt.plot(all_data['time'])
            plt.grid()
            plt.xlabel('Configurations')
            plt.ylabel('Time seconds')
            plt.ylim(bottom=0)
            plt.title(f"Time Distribution for Environment {env}")# and Algorithm {algo}")
            plt.show()
        except:
            pass
# Out:
# Max transfer time for env S2_C2_N50 :     351.492678
# Average transfer time for env S2_C2_N50 : 186.71872525959367
# Min transfer time for env S2_C2_N50 :     86.565136
# Max throughput for env S2_C2_N50 :     89.13220717402905
# Max transfer time for env S2_C8_N50 :     288.668689
# Average transfer time for env S2_C8_N50 : 143.96124752595938
# Min transfer time for env S2_C8_N50 :     54.692666
# Max throughput for env S2_C8_N50 :     141.07452059477222
# Max transfer time for env S4_C16_N50 :     223.349842
# Average transfer time for env S4_C16_N50 : 116.62815741309255
# Min transfer time for env S4_C16_N50 :     51.727285
# Max throughput for env S4_C16_N50 :     149.16192945367226
# Max transfer time for env S8_C8_N50 :     223.332953
# Average transfer time for env S8_C8_N50 : 114.48244875846501
# Min transfer time for env S8_C8_N50 :     51.601743
# Max throughput for env S8_C8_N50 :     149.52482585714208
# Max transfer time for env S8_C2_N50 :     344.493572
# Average transfer time for env S8_C2_N50 : 174.7224549819413
# Min transfer time for env S8_C2_N50 :     81.584634
# Max throughput for env S8_C2_N50 :     94.57346632210178
# Max transfer time for env S8_C16_N50 :     223.241779
# Average transfer time for env S8_C16_N50 : 114.52478378555304
# Min transfer time for env S8_C16_N50 :     51.624196
# Max throughput for env S8_C16_N50 :     149.45979276849172
# Max transfer time for env S16_C4_N50 :     223.340563
# Average transfer time for env S16_C4_N50 : 116.59759748984199
# Min transfer time for env S16_C4_N50 :     51.7693
# Max throughput for env S16_C4_N50 :     149.04087240893733
# Max transfer time for env S16_C8_N50 :     223.219939
# Average transfer time for env S16_C8_N50 : 114.41104192776524
# Min transfer time for env S16_C8_N50 :     51.629817
# Max throughput for env S16_C8_N50 :     149.44352090188502
# Max transfer time for env S16_C16_N50 :     223.304092
# Average transfer time for env S16_C16_N50 : 114.38078718284424
# Min transfer time for env S16_C16_N50 :     51.696277
# Max throughput for env S16_C16_N50 :     149.25139843242482
# Max transfer time for env S2_C2_N150 :     364.734245
# Average transfer time for env S2_C2_N150 : 176.74573794582392
# Min transfer time for env S2_C2_N150 :     90.590323
# Max throughput for env S2_C2_N150 :     85.17180842814746
# Max transfer time for env S2_C8_N150 :     293.667138
# Average transfer time for env S2_C8_N150 : 120.35960671783296
# Min transfer time for env S2_C8_N150 :     42.628538
# Max throughput for env S2_C8_N150 :     180.9994430491611
# Max transfer time for env S4_C16_N150 :     134.549981
# Average transfer time for env S4_C16_N150 : 70.63662084875847
# Min transfer time for env S4_C16_N150 :     26.739411
# Max throughput for env S4_C16_N150 :     288.55316356818776
# Max transfer time for env S8_C8_N150 :     127.449384
# Average transfer time for env S8_C8_N150 : 61.51859742437923
# Min transfer time for env S8_C8_N150 :     24.656979
# Max throughput for env S8_C8_N150 :     312.9232350808264
# Max transfer time for env S8_C2_N150 :     352.471673
# Average transfer time for env S8_C2_N150 : 164.80460792325056
# Min transfer time for env S8_C2_N150 :     88.556194
# Max throughput for env S8_C2_N150 :     87.12819835052983
# Max transfer time for env S8_C16_N150 :     129.567438
# Average transfer time for env S8_C16_N150 : 60.79751492099323
# Min transfer time for env S8_C16_N150 :     20.652707
# Max throughput for env S8_C16_N150 :     373.59468838636985
# Max transfer time for env S16_C4_N150 :     138.279781
# Average transfer time for env S16_C4_N150 : 81.6220091557562
# Min transfer time for env S16_C4_N150 :     38.469669
# Max throughput for env S16_C4_N150 :     200.5668839001448
# Max transfer time for env S16_C8_N150 :     127.615135
# Average transfer time for env S16_C8_N150 : 60.77236766139955
# Min transfer time for env S16_C8_N150 :     24.213183
# Max throughput for env S16_C8_N150 :     318.65870901814105
# Max transfer time for env S16_C16_N150 :     127.715255
# Average transfer time for env S16_C16_N150 : 59.98910508108108
# Min transfer time for env S16_C16_N150 :     19.682942
# Max throughput for env S16_C16_N150 :     392.0014414511814
# Max transfer time for env S2_C2_N1000 :     348.104158
# Average transfer time for env S2_C2_N1000 : 178.0215314572072
# Min transfer time for env S2_C2_N1000 :     85.623084
# Max throughput for env S2_C2_N1000 :     90.11286764676684
# Max transfer time for env S2_C8_N1000 :     293.627906
# Average transfer time for env S2_C8_N1000 : 119.60008977426637
# Min transfer time for env S2_C8_N1000 :     27.164906
# Max throughput for env S2_C8_N1000 :     284.0334377008336
# Max transfer time for env S4_C16_N1000 :     133.520644
# Average transfer time for env S4_C16_N1000 : 64.53318729119638
# Min transfer time for env S4_C16_N1000 :     21.558693
# Max throughput for env S4_C16_N1000 :     357.89468480301656
# Max transfer time for env S8_C8_N1000 :     130.284312
# Average transfer time for env S8_C8_N1000 : 53.98396142117117
# Min transfer time for env S8_C8_N1000 :     22.545835
# Max throughput for env S8_C8_N1000 :     342.2247007484974
# Max transfer time for env S8_C2_N1000 :     348.513006
# Average transfer time for env S8_C2_N1000 : 165.88115045372462
# Min transfer time for env S8_C2_N1000 :     83.568042
# Max throughput for env S8_C2_N1000 :     92.32885504245748
# Max transfer time for env S8_C16_N1000 :     126.485194
# Average transfer time for env S8_C16_N1000 : 51.47507715505618
# Min transfer time for env S8_C16_N1000 :     13.655796
# Max throughput for env S8_C16_N1000 :     565.0158830726527
# Max transfer time for env S16_C4_N1000 :     140.239828
# Average transfer time for env S16_C4_N1000 : 79.5342387020316
# Min transfer time for env S16_C4_N1000 :     37.574473
# Max throughput for env S16_C4_N1000 :     205.34530546842268
# Max transfer time for env S16_C8_N1000 :     127.735811
# Average transfer time for env S16_C8_N1000 : 53.38509259009009
# Min transfer time for env S16_C8_N1000 :     21.555353
# Max throughput for env S16_C8_N1000 :     357.950140552094
# Max transfer time for env S16_C16_N1000 :     127.540882
# Average transfer time for env S16_C16_N1000 : 49.72368279954955
# Min transfer time for env S16_C16_N1000 :     12.609745
# Max throughput for env S16_C16_N1000 :     611.8872059664965

# %%
for file in file_list:
    try:

        df = pd.read_csv(file)
        df = df[df['time'] > 0]
          
        
        env = file.split("/")[-1].split("\\")[-3]
        algo = file.split("\\")[-2]

        print(f"Env :{env}  Samples  {len(df[df['time'].notna()])}")
    
    except:
        pass

# %%
import glob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
from datetime import datetime, timedelta
import glob
import pandas as pd
import seaborn as sns
import statistics
import numpy as np
import pandas as pd
import seaborn as sns
import glob, os
import matplotlib.pyplot as plt

def get_file_list(base_path, signatures):
    """Generate file lists for the given base path and environment signatures."""
    return [glob.glob(f"{base_path}/{signature}_random_sample*.csv") for signature in signatures]

def load_and_filter_data(file_list, max_config_id, time_threshold=2):
    """Load and filter data based on time and config_id."""
    data_frames = []
    for file in file_list:
        df = pd.read_csv(file)
        df = df[(df['time'] > time_threshold) & (df['config_id'] < max_config_id)]
        data_frames.append(df)
    return pd.concat(data_frames, axis=0, ignore_index=True) if data_frames else pd.DataFrame()

BASE_PATH = "C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_1310k"



ENV_SIGNATURES_NEW_BASE_ENVS = [
    "S2_C2_N50","S2_C8_N50","S4_C16_N50",
    "S8_C8_N50","S8_C2_N50",
    "S16_C4_N50","S16_C16_N50", "S16_C8_N50",
    
    "S2_C2_N150","S2_C8_N150","S4_C16_N150",
    "S8_C8_N150","S8_C2_N150",
    "S16_C4_N150","S16_C16_N150", "S16_C8_N150",
    
    "S2_C2_N1000","S2_C8_N1000","S4_C16_N1000",
    "S8_C8_N1000","S8_C2_N1000", "S16_C8_N1000",
    "S16_C4_N1000","S16_C16_N1000",

]


env_lists = {
    #"SCALE_COMPUTE": ENV_SIGNATURES_SCALE_COMPUTE,
    #"SCALE_NETWORK": ENV_SIGNATURES_SCALE_NETWORK,
    "NEW_BASE":ENV_SIGNATURES_NEW_BASE_ENVS
}
total_count = 0
total_seconds = 0
for name, env_list in env_lists.items():
    
    file_lists = get_file_list(BASE_PATH, env_list)
    df_heatmap = pd.DataFrame(0, index=env_list, columns=env_list, dtype=float)
    
    N = 66
    for i, file_list in enumerate(file_lists):

        env = ""
        algo = ""
    
        all_data = pd.DataFrame()
        list_single_dfs_1310k = []
    
        for file in file_list:
    
            
            df = pd.read_csv(file)
            true_count = len(df)

            df = df[df['time'] > 0]
            env = file.split("/")[-1].split("\\")[-1].replace("_random_samples.csv","")

            avg = statistics.mean(df['time'])
            count = len(df[df['time'].notna()])

            goal = 325
            missing_count = (goal - true_count)
            seconds = avg * missing_count
            
            if seconds < 0 : 
                seconds = 0
                missing_count = 0
                
            total_seconds = total_seconds + seconds + (15 * missing_count)

            print(f"Env : {env}  Samples  {true_count} ({count} -> {true_count - count})   missing to {goal} : {missing_count} , avg = {avg:.1f}s, est. time = {seconds:.1f}s")

            total_count = total_count + count

print(f"Total Sample Count : {total_count}")
print(f"\nTotal Seconds : {total_seconds}")  
print(f"Total Minutes : {total_seconds / 60}") 
print(f"Total Hours : {total_seconds / 60 / 60}") 
print(f"Total Hours / 3 : {total_seconds / 60 / 60 / 3}") 


current_time = datetime.now()
hours_to_add = total_seconds / 60 / 60 / 3
hours = int(hours_to_add)
minutes = int((hours_to_add - hours) * 60)
time_delta = timedelta(hours=hours, minutes=minutes)
new_time = current_time + time_delta

print("Current time:            ", current_time.strftime("%Y-%m-%d %H:%M:%S"))
print("Estimated finishing time:", new_time.strftime("%Y-%m-%d %H:%M:%S"))
# 24 * 150 = 3600
# 24 * 200 = 4800
# 24 * 210 = 5040
# Out:
# Env : S2_C2_N50  Samples  350 (330 -> 20)   missing to 325 : 0 , avg = 124.0s, est. time = 0.0s
# Env : S2_C8_N50  Samples  350 (331 -> 19)   missing to 325 : 0 , avg = 124.0s, est. time = 0.0s
# Env : S4_C16_N50  Samples  350 (325 -> 25)   missing to 325 : 0 , avg = 119.5s, est. time = 0.0s
# Env : S8_C8_N50  Samples  350 (324 -> 26)   missing to 325 : 0 , avg = 118.7s, est. time = 0.0s
# Env : S8_C2_N50  Samples  348 (325 -> 23)   missing to 325 : 0 , avg = 119.1s, est. time = 0.0s
# Env : S16_C4_N50  Samples  325 (306 -> 19)   missing to 325 : 0 , avg = 118.9s, est. time = 0.0s
# Env : S16_C16_N50  Samples  325 (305 -> 20)   missing to 325 : 0 , avg = 118.6s, est. time = 0.0s
# Env : S16_C8_N50  Samples  325 (305 -> 20)   missing to 325 : 0 , avg = 118.6s, est. time = 0.0s
# Env : S2_C2_N150  Samples  325 (319 -> 6)   missing to 325 : 0 , avg = 78.7s, est. time = 0.0s
# Env : S2_C8_N150  Samples  325 (317 -> 8)   missing to 325 : 0 , avg = 78.6s, est. time = 0.0s
# Env : S4_C16_N150  Samples  325 (319 -> 6)   missing to 325 : 0 , avg = 55.6s, est. time = 0.0s
# Env : S8_C8_N150  Samples  325 (309 -> 16)   missing to 325 : 0 , avg = 53.7s, est. time = 0.0s
# Env : S8_C2_N150  Samples  325 (303 -> 22)   missing to 325 : 0 , avg = 53.5s, est. time = 0.0s
# Env : S16_C4_N150  Samples  325 (305 -> 20)   missing to 325 : 0 , avg = 53.3s, est. time = 0.0s
# Env : S16_C16_N150  Samples  325 (308 -> 17)   missing to 325 : 0 , avg = 53.5s, est. time = 0.0s
# Env : S16_C8_N150  Samples  325 (311 -> 14)   missing to 325 : 0 , avg = 53.5s, est. time = 0.0s
# Env : S2_C2_N1000  Samples  325 (322 -> 3)   missing to 325 : 0 , avg = 72.9s, est. time = 0.0s
# Env : S2_C8_N1000  Samples  325 (321 -> 4)   missing to 325 : 0 , avg = 72.9s, est. time = 0.0s
# Env : S4_C16_N1000  Samples  325 (314 -> 11)   missing to 325 : 0 , avg = 46.6s, est. time = 0.0s
# Env : S8_C8_N1000  Samples  324 (312 -> 12)   missing to 325 : 1 , avg = 41.9s, est. time = 41.9s
# Env : S8_C2_N1000  Samples  325 (300 -> 25)   missing to 325 : 0 , avg = 42.5s, est. time = 0.0s
# Env : S16_C8_N1000  Samples  325 (311 -> 14)   missing to 325 : 0 , avg = 41.5s, est. time = 0.0s
# Env : S16_C4_N1000  Samples  325 (313 -> 12)   missing to 325 : 0 , avg = 41.4s, est. time = 0.0s
# Env : S16_C16_N1000  Samples  325 (312 -> 13)   missing to 325 : 0 , avg = 41.5s, est. time = 0.0s
# Total Sample Count : 7547
#
# Total Seconds : 56.934923272435896
# Total Minutes : 0.9489153878739316
# Total Hours : 0.015815256464565528
# Total Hours / 3 : 0.005271752154855176
# Current time:             2025-02-03 12:23:56
# Estimated finishing time: 2025-02-03 12:23:56

# %%
import glob
import pandas as pd
import numpy as np
import yaml
from datetime import datetime, timedelta
import glob
import pandas as pd
import pandas as pd
from collections import Counter

def get_file_list(base_path, signatures):
    """Generate file lists for the given base path and environment signatures."""
    return [glob.glob(f"{base_path}/{signature}_random_sample*.csv") for signature in signatures]

def load_and_filter_data(file_list, max_config_id, time_threshold=2):
    """Load and filter data based on time and config_id."""
    data_frames = []
    for file in file_list:
        df = pd.read_csv(file)
        df = df[(df['time'] > time_threshold) & (df['config_id'] < max_config_id)]
        data_frames.append(df)
    return pd.concat(data_frames, axis=0, ignore_index=True) if data_frames else pd.DataFrame()
    
BASE_PATH = "C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/random_samples_10_5M"


ENV_SIGNATURES_NEW_BASE_ENVS = [
    "S2_C2_N50","S2_C8_N50","S4_C16_N50","S8_C8_N50","S8_C2_N50","S8_C16_N50","S16_C4_N50","S16_C8_N50","S16_C16_N50",
                             "S2_C2_N150","S2_C8_N150","S4_C16_N150","S8_C8_N150","S8_C2_N150","S8_C16_N150","S16_C4_N150","S16_C8_N150","S16_C16_N150",
                             "S2_C2_N1000","S2_C8_N1000","S4_C16_N1000","S8_C8_N1000","S8_C2_N1000","S8_C16_N1000","S16_C4_N1000","S16_C8_N1000","S16_C16_N1000"
]


env_lists = {
    "NEW_BASE":ENV_SIGNATURES_NEW_BASE_ENVS,
}

overall_counts = Counter()

dict_env_count = {}

for name, env_list in env_lists.items():
    file_lists = get_file_list(BASE_PATH, env_list)
    for i, file_list in enumerate(file_lists):

        for file in file_list:    
            
            df = pd.read_csv(file)
            df = df[df['run'] == -1] 
            env = file.split("/")[-1].split("\\")[-1].replace("_random_samples.csv","")

            if env not in dict_env_count.keys():
                dict_env_count[env] = 0

            dict_env_count[env] = dict_env_count[env] + len(df)
            
            value_counts = df['host'].value_counts()
            overall_counts.update(value_counts.to_dict())

overall_statistics = pd.Series(overall_counts)

overall_statistics = overall_statistics.sort_values(ascending=False)
print(overall_statistics)           

print(yaml.dump(dict_env_count))
# Out:
# -1    38
# dtype: int64
# S16_C4_N50: 2
# S2_C2_N50: 6
# S2_C8_N50: 6
# S4_C16_N50: 6
# S8_C16_N50: 6
# S8_C2_N50: 6
# S8_C8_N50: 6

# %%
import glob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
from datetime import datetime, timedelta
import glob
import pandas as pd
import seaborn as sns
import statistics
import numpy as np
import pandas as pd
import seaborn as sns
import glob, os
import matplotlib.pyplot as plt

all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_10_5M*/*/*/*.csv')

dict_env_df = {}

for file in all_files:
    df = pd.read_csv(file)

    env = file.split("\\")[-3]
    algo = file.split("\\")[-2]

    
    df = pd.read_csv(file)
    df = df[df['transfer_id'] > 1]
    if env not in dict_env_df.keys(): 
        dict_env_df[env] = []
    dict_env_df[env].append(df)


    
for env in dict_env_df.keys():
    
    all_data = pd.concat(dict_env_df[env], axis=0, ignore_index=True)
    
    all_data = all_data.sort_values(by='uncompressed_throughput',ascending=False).reset_index(drop=True)

    
    #'''
    df = all_data

    df = df[df.buffer_size.isin([64, 256, 512, 1024])]

    #df.to_csv(f'C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/currated_datasets/{env}_currated_dataset.csv')
    #print(file)
    df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
    df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])
    
    
    pd.to_numeric(df['client_bufpool_factor'], downcast='integer', errors='coerce')
    pd.to_numeric(df['server_bufpool_factor'], downcast='integer', errors='coerce')


    
    highest_throughput = df['uncompressed_throughput'].max()

    subset = df[df['uncompressed_throughput'] >= highest_throughput * 0.8]
    subset_rest = df[df['uncompressed_throughput'] < highest_throughput * 0.8]

    indices = np.linspace(0, len(subset) - 1, num=100, dtype=int)
    equally_sampled_subset = subset.iloc[indices].reset_index(drop=True)

    indices_rest = np.linspace(0, len(subset_rest), num=100, dtype=int)
    equally_sampled_subset_rest = subset_rest.iloc[indices_rest].reset_index(drop=True)

    equally_sampled_subset = pd.concat([equally_sampled_subset,equally_sampled_subset_rest])
    
    result = equally_sampled_subset
    


    all_data = result.sort_values(by='uncompressed_throughput',ascending=False).reset_index(drop=True)
    all_data = all_data.drop("Unnamed: 0",axis=1)
    #all_data.to_csv(f'C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/currated_datasets/{env}_currated_dataset.csv', index=False)
    #'''


    
    print(f"Max transfer throughput for env {env} :     {all_data['uncompressed_throughput'].max()}")
    print(f"Average transfer throughput for env {env} : {statistics.mean(all_data['uncompressed_throughput'])}")
    print(f"Min transfer throughput for env {env} :     {all_data['uncompressed_throughput'].min()}")
        
    plt.figure(figsize=(8, 5))
        
    plt.plot(all_data['uncompressed_throughput'])
    plt.grid()
    plt.xlabel('Configurations')
    plt.ylabel('Throughput MB/s')
    plt.ylim(bottom=0)
    plt.title(f"Throughput Distribution for Environment {env}")# and Algorithm {algo}")
    plt.show()
# Out:
# Max transfer throughput for env S16_C16_N1000 :     531.5470318104626
# Average transfer throughput for env S16_C16_N1000 : 526.7334235441684
# Min transfer throughput for env S16_C16_N1000 :     523.5784184009368
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])
# Max transfer throughput for env S16_C4_N1000 :     160.58797722721297
# Average transfer throughput for env S16_C4_N1000 : 148.52471162991523
# Min transfer throughput for env S16_C4_N1000 :     138.2060546453083
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
# Max transfer throughput for env S16_C8_N1000 :     316.76483253988255
# Average transfer throughput for env S16_C8_N1000 : 299.2549556777121
# Min transfer throughput for env S16_C8_N1000 :     281.5438723423618
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])
# Max transfer throughput for env S2_C2_N50 :     81.6692288228573
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])
# Average transfer throughput for env S2_C2_N50 : 75.55534457565646
# Min transfer throughput for env S2_C2_N50 :     70.25642300517798
# Max transfer throughput for env S2_C8_N50 :     121.42737649839216
# Average transfer throughput for env S2_C8_N50 : 113.4946681862384
# Min transfer throughput for env S2_C8_N50 :     108.61243427942917
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
# Max transfer throughput for env S4_C16_N50 :     121.13750982332344
# Average transfer throughput for env S4_C16_N50 : 112.01322702322277
# Min transfer throughput for env S4_C16_N50 :     105.0665997754746
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
# Max transfer throughput for env S8_C16_N150 :     314.682738971838
# Average transfer throughput for env S8_C16_N150 : 301.5873222260875
# Min transfer throughput for env S8_C16_N150 :     290.4646345959782
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])
# Max transfer throughput for env S8_C2_N150 :     79.14939449916677
# Average transfer throughput for env S8_C2_N150 : 73.65896417260865
# Min transfer throughput for env S8_C2_N150 :     67.84369723741607
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['client_bufpool_factor'] = df['client_bufferpool_size'] / df['buffer_size'] / 2 / (df['write_par'] + df['ser_par'] + df['decomp_par'] + df['rcv_par'])
# Max transfer throughput for env S8_C8_N150 :     316.6326311850332
# Average transfer throughput for env S8_C8_N150 : 309.02056259826065
# Min transfer throughput for env S8_C8_N150 :     300.6634900585811
# C:\Users\bened\AppData\Local\Temp\ipykernel_12376\875135766.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['server_bufpool_factor'] = df['server_bufferpool_size'] / df['buffer_size'] / 2 / (df['read_par'] + df['deser_par'] + df['comp_par'] + df['send_par'])

# %%
import glob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
from datetime import datetime, timedelta
import glob
import pandas as pd
import seaborn as sns
import statistics
import numpy as np
import pandas as pd
import seaborn as sns
import glob, os
import matplotlib.pyplot as plt

all_files = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results_10_5M*/*/*/*.csv')

dict_env_df = {}

for file in all_files:
    df = pd.read_csv(file)

    env = file.split("\\")[-3]
    algo = file.split("\\")[-2]

    
    df = pd.read_csv(file)
    df = df[df['transfer_id'] > 1]
    if env not in dict_env_df.keys(): 
        dict_env_df[env] = []
    dict_env_df[env].append(df)


    if len(df['host'].unique()) > 1:
        print(file)
        print("\n")
# Out:
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_10_5M\S16_C16_N1000\cost_model_xgb_rs_exc_cluster_update_only_hist_v9\results_cost_model_xgb_rs_exc_cluster_update_only_hist_v9_2025-02-17_11-42-18.csv
#
#
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_10_5M\S8_C16_N150\cost_model_xgb_rs_exc_cluster_update_only_hist_v9\results_cost_model_xgb_rs_exc_cluster_update_only_hist_v9_2025-02-17_11-19-55.csv
#
#
# C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer\results_10_5M_semi_flex\S2_C8_N50\cost_model_xgb_rs_exc_cluster_update_only_hist_v17\results_cost_model_xgb_rs_exc_cluster_update_only_hist_v17_2025-02-18_11-35-17.csv
