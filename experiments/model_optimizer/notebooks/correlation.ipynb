# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob as glob

# %%
file_list_env_1 = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results/S16_C16_N1000/random_*/*.csv')
file_list_env_2 = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results/S16_C8_N100/random_*/*.csv')
file_list_env_3 = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results/S8_C1_N50/random_*/*.csv')
file_list_env_4 = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results/S16_C16_N10000/random_*/*.csv')
file_list_env_5 = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results/S16_C4_N10/random_*/*.csv')
file_list_env_6 = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results/S8_C8_N500/random_*/*.csv')
file_list_env_7 = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results/S2_C2_N20/random_*/*.csv')
file_list_env_8 = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results/S16_C1_N1000/random_*/*.csv')
file_list_env_9 = glob.glob('C:/Users/bened/Desktop/Uni/repos/xdbc-client/experiments/model_optimizer/results/S16_C1_N10/random_*/*.csv')

file_lists = [file_list_env_1,file_list_env_2,file_list_env_3,file_list_env_4,file_list_env_5,file_list_env_6,file_list_env_7,file_list_env_8,file_list_env_9]

# %%
list_single_dfs = []

for file_list in file_lists:

    env = ""
    algo = ""

    all_data = pd.DataFrame()


    for file in file_list:
        
    
        env = file.split("/")[-1].split("\\")[0]
        algo = file.split("\\")[-2]

        df = pd.read_csv(file)

        list_single_dfs.append(df)
        
dataframe = pd.concat(list_single_dfs, axis=0, ignore_index=True)

dataframe = dataframe[dataframe['time'].notna()]

dataframe = dataframe[[
#'transfer_id',
'total_time_x',
'rcv_wait_time',
'rcv_proc_time',
'rcv_throughput',
'rcv_throughput_pb',
'rcv_load',
'decomp_wait_time',
'decomp_proc_time',
'decomp_throughput',
'decomp_throughput_pb',
'decomp_load',
'write_wait_time',
'write_proc_time',
'write_throughput',
'write_throughput_pb',
'write_load',
'total_time_y',
'read_wait_time',
'read_proc_time',
'read_throughput',
'read_throughput_pb',
'read_load',
'deser_wait_time',
'deser_proc_time',
'deser_throughput',
'deser_throughput_pb',
'deser_load',
'comp_wait_time',
'comp_proc_time',
'comp_throughput',
'comp_throughput_pb',
'comp_load',
'send_wait_time',
'send_proc_time',
'send_throughput',
'send_throughput_pb',
'send_load',
#'date',
#'xdbc_version',
#'host',
#'run',
#'source_system',
#'target_system',
#'table',
#'compression',
#'format',
'send_par',
'rcv_par',
'server_bufferpool_size',
'client_bufferpool_size',
'buffer_size',
'network',
#'network_latency',
#'network_loss',
#'client_readmode',
'client_cpu',
'server_cpu',
'write_par',
'decomp_par',
'read_par',
#'read_partitions',
'deser_par',
'comp_par',
'time',
'datasize',
#'avg_cpu_server',
#'avg_cpu_client',
#'timestamp_end',
'throughput',
'average_throughput',
#'resource_utilization',
'wait_to_proc_time_ratio',
'even_load_distribution_mse',
#'trial_id',
#'algo'
]]

# %%
plt.figure(figsize=(20, 16))
heatmap = sns.heatmap(dataframe.corr());

plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')
